# %%
import pandas as pd
import matplotlib.pyplot as pp
import numpy as np
import seaborn as sns
import os
from urllib.request import urlopen, Request
import requests as r
from sys import argv, exit
from base64 import b64encode
import json

from dotenv import load_dotenv, find_dotenv
dotenv_path=find_dotenv()
load_dotenv(dotenv_path)
client_id= os.environ.get('SPOTIFY_CLIENT_ID')
client_secret= os.environ.get('SPOTIFY_CLIENT_SECRET')

import spotipy
import sys
from sys import argv, exit
from spotipy.oauth2 import SpotifyClientCredentials

#Authentication without user
client_credentials_manager= SpotifyClientCredentials(client_id= client_id, client_secret=client_secret)
sp= spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
kpop_00_data= pd.read_csv('/Users/josephlim/Downloads/KPopHits2000.csv')
kpop_21_data=pd.read_csv('/Users/josephlim/Downloads/KPopHits2021.csv')
us_98to20_data=pd.read_csv('/Users/josephlim/Downloads/songs_normalize.csv')
us_21_data= pd.read_csv('/Users/josephlim/Downloads/spotify-charts.csv')

# %%
kpop_00_data.isna().any()
# Out:
# Unnamed: 0        False
# title             False
# artist/s          False
# danceability      False
# energy            False
# key               False
# loudness          False
# mode              False
# speechiness       False
# acousticness      False
# valence           False
# tempo             False
# duration_ms       False
# time_signature    False
# dtype: bool

# %%
kpop_21_data.isna().any()
# Out:
# Unnamed: 0        False
# title             False
# artist/s          False
# danceability      False
# energy            False
# key               False
# loudness          False
# mode              False
# speechiness       False
# acousticness      False
# valence           False
# tempo             False
# duration_ms       False
# time_signature    False
# dtype: bool

# %%
us_21_data.isna().any()
# Out:
# Unnamed: 0           False
# Position             False
# Track Name           False
# Streams              False
# Chart Start Date     False
# Chart End Date       False
# Album Name           False
# Release Date         False
# Artist               False
# Features             False
# Song Duration(ms)    False
# Explicit             False
# Url                  False
# dtype: bool

# %%
us_98to20_data.isna().any()
# Out:
# artist              False
# song                False
# duration_ms         False
# explicit            False
# year                False
# popularity          False
# danceability        False
# energy              False
# key                 False
# loudness            False
# mode                False
# speechiness         False
# acousticness        False
# instrumentalness    False
# liveness            False
# valence             False
# tempo               False
# genre               False
# dtype: bool

# %%
kpop_00_data.describe()
# Out:
#        Unnamed: 0  danceability     energy        key   loudness       mode  \
# count   30.000000     30.000000  30.000000  30.000000  30.000000  30.000000
# mean    14.500000      0.605633   0.676100   4.233333  -6.617667   0.566667
# std      8.803408      0.155947   0.213711   3.793673   3.568555   0.504007
# min      0.000000      0.330000   0.233000   0.000000 -15.467000   0.000000
# 25%      7.250000      0.474000   0.530750   0.000000  -7.800500   0.000000
# 50%     14.500000      0.631500   0.736500   3.500000  -6.134500   1.000000
# 75%     21.750000      0.729000   0.833000   8.000000  -4.090250   1.000000
# max     29.000000      0.838000   0.997000   9.000000  -1.820000   1.000000
#
#        speechiness  acousticness    valence       tempo    duration_ms  \
# count    30.000000     30.000000  30.000000   30.000000      30.000000
# mean      0.058683      0.239880   0.545703  127.925267  242037.000000
# std       0.040504      0.264849   0.280608   25.270631   54347.072547
# min       0.026900      0.000427   0.082100   74.692000   48248.000000
# 25%       0.034425      0.028625   0.250000  118.443750  215259.250000
# 50%       0.042150      0.118000   0.656500  132.017000  236705.500000
# 75%       0.066825      0.405250   0.733500  142.283500  260552.250000
# max       0.180000      0.913000   0.971000  179.482000  340907.000000
#
#        time_signature
# count       30.000000
# mean         3.966667
# std          0.182574
# min          3.000000
# 25%          4.000000
# 50%          4.000000
# 75%          4.000000
# max          4.000000

# %%
kpop_21_data.describe()
# Out:
#        Unnamed: 0  danceability     energy        key   loudness       mode  \
# count    50.00000     50.000000  50.000000  50.000000  50.000000  50.000000
# mean     24.50000      0.681860   0.787920   5.280000  -3.790740   0.620000
# std      14.57738      0.117991   0.127271   3.779861   1.976335   0.490314
# min       0.00000      0.311000   0.377000   0.000000 -10.121000   0.000000
# 25%      12.25000      0.609000   0.735750   1.250000  -5.040500   0.000000
# 50%      24.50000      0.690500   0.818500   6.000000  -3.593000   1.000000
# 75%      36.75000      0.765500   0.869750   9.000000  -2.230000   1.000000
# max      49.00000      0.883000   0.963000  11.000000  -0.384000   1.000000
#
#        speechiness  acousticness    valence       tempo    duration_ms  \
# count    50.000000     50.000000  50.000000   50.000000      50.000000
# mean      0.089900      0.097556   0.577220  126.758600  197322.080000
# std       0.053693      0.123401   0.192103   27.460848   20728.437265
# min       0.035100      0.000707   0.135000   61.450000  149214.000000
# 25%       0.054075      0.018575   0.445500  109.985750  184140.250000
# 50%       0.076800      0.054650   0.638000  124.975500  195680.000000
# 75%       0.103250      0.118500   0.721250  147.963250  212248.500000
# max       0.280000      0.594000   0.922000  188.700000  247360.000000
#
#        time_signature
# count            50.0
# mean              4.0
# std               0.0
# min               4.0
# 25%               4.0
# 50%               4.0
# 75%               4.0
# max               4.0

# %%
us_21_data.describe()
# Out:
#         Unnamed: 0     Position  Song Duration(ms)
# count  1260.000000  1260.000000        1260.000000
# mean    629.500000    15.500000      198219.403175
# std     363.874979     8.658878       38673.538380
# min       0.000000     1.000000      121572.000000
# 25%     314.750000     8.000000      170813.000000
# 50%     629.500000    15.500000      199604.000000
# 75%     944.250000    23.000000      216258.250000
# max    1259.000000    30.000000      383036.000000

# %%
us_98to20_data.describe()
# Out:
#          duration_ms        year   popularity  danceability       energy  \
# count    2000.000000  2000.00000  2000.000000   2000.000000  2000.000000
# mean   228748.124500  2009.49400    59.872500      0.667437     0.720366
# std     39136.569008     5.85996    21.335577      0.140416     0.152745
# min    113000.000000  1998.00000     0.000000      0.129000     0.054900
# 25%    203580.000000  2004.00000    56.000000      0.581000     0.622000
# 50%    223279.500000  2010.00000    65.500000      0.676000     0.736000
# 75%    248133.000000  2015.00000    73.000000      0.764000     0.839000
# max    484146.000000  2020.00000    89.000000      0.975000     0.999000
#
#                key     loudness         mode  speechiness  acousticness  \
# count  2000.000000  2000.000000  2000.000000  2000.000000   2000.000000
# mean      5.378000    -5.512435     0.553500     0.103568      0.128955
# std       3.615059     1.933482     0.497254     0.096159      0.173346
# min       0.000000   -20.514000     0.000000     0.023200      0.000019
# 25%       2.000000    -6.490250     0.000000     0.039600      0.014000
# 50%       6.000000    -5.285000     1.000000     0.059850      0.055700
# 75%       8.000000    -4.167750     1.000000     0.129000      0.176250
# max      11.000000    -0.276000     1.000000     0.576000      0.976000
#
#        instrumentalness     liveness      valence        tempo
# count       2000.000000  2000.000000  2000.000000  2000.000000
# mean           0.015226     0.181216     0.551690   120.122558
# std            0.087771     0.140669     0.220864    26.967112
# min            0.000000     0.021500     0.038100    60.019000
# 25%            0.000000     0.088100     0.386750    98.985750
# 50%            0.000000     0.124000     0.557500   120.021500
# 75%            0.000068     0.241000     0.730000   134.265500
# max            0.985000     0.853000     0.973000   210.851000

# %%
us_21_data.head()
# Out:
#    Unnamed: 0  Position                                        Track Name  \
# 0           0         1                              Easy On Me by Adele
# 1           1         2       STAY (with Justin Bieber) by The Kid LAROI
# 2           2         3   INDUSTRY BABY (feat. Jack Harlow) by Lil Nas X
# 3           3         4                      Heat Waves by Glass Animals
# 4           4         5                                    MONEY by LISA
#
#       Streams Chart Start Date Chart End Date                  Album Name  \
# 0  57,081,735       2021-10-22     2021-10-29                  Easy On Me
# 1  43,772,708       2021-10-22     2021-10-29       F*CK LOVE 3: OVER YOU
# 2  38,131,363       2021-10-22     2021-10-29                     MONTERO
# 3  30,071,945       2021-10-22     2021-10-29  Dreamland (+ Bonus Levels)
# 4  27,961,856       2021-10-22     2021-10-29                      LALISA
#
#   Release Date         Artist       Features  Song Duration(ms)  Explicit  \
# 0   2021-10-14          Adele           None             224694     False
# 1   2021-07-23  The Kid LAROI  Justin Bieber             141805      True
# 2   2021-09-17      Lil Nas X    Jack Harlow             212352      True
# 3   2020-08-06  Glass Animals           None             238805     False
# 4   2021-09-10           LISA           None             168227     False
#
#                                                  Url
# 0  https://open.spotify.com/track/0gplL1WMoJ6iYaP...
# 1  https://open.spotify.com/track/5PjdY0CKGZdEuoN...
# 2  https://open.spotify.com/track/5Z9KJZvQzH6PFmb...
# 3  https://open.spotify.com/track/02MWAaffLxlfxAU...
# 4  https://open.spotify.com/track/7hU3IHwjX150XLo...

# %%
top100_USA2021_url= 'https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2021#cite_note-4'
top100us_data= pd.read_html(top100_USA2021_url)

# %%
type(top100us_data)
# Out:
# list

# %%
len(top100us_data)
# Out:
# 2

# %%
top100us_data=top100us_data[0]

# %%
top100us_data= top100us_data.iloc[:,:3]
top100us_data
# Out:
#     No.                                Title  \
# 0     1                         "Levitating"
# 1     2                    "Save Your Tears"
# 2     3                    "Blinding Lights"
# 3     4                               "Mood"
# 4     5                           "Good 4 U"
# ..  ...                                  ...
# 95   96           "Things a Man Oughta Know"
# 96   97              "Throat Baby (Go Baby)"
# 97   98                          "Tombstone"
# 98   99  "Drinkin' Beer. Talkin' God. Amen."
# 99  100                         "Todo de Ti"
#
#                                     Artist(s)
# 0                                    Dua Lipa
# 1                The Weeknd and Ariana Grande
# 2                                  The Weeknd
# 3                24kGoldn featuring Iann Dior
# 4                              Olivia Rodrigo
# ..                                        ...
# 95                              Lainey Wilson
# 96                                   BRS Kash
# 97                                   Rod Wave
# 98  Chase Rice featuring Florida Georgia Line
# 99                             Rauw Alejandro
#
# [100 rows x 3 columns]

# %%
top100us_data.set_index('No.', inplace=True)
top100us_data
# Out:
#                                    Title  \
# No.
# 1                           "Levitating"
# 2                      "Save Your Tears"
# 3                      "Blinding Lights"
# 4                                 "Mood"
# 5                             "Good 4 U"
# ..                                   ...
# 96            "Things a Man Oughta Know"
# 97               "Throat Baby (Go Baby)"
# 98                           "Tombstone"
# 99   "Drinkin' Beer. Talkin' God. Amen."
# 100                         "Todo de Ti"
#
#                                      Artist(s)
# No.
# 1                                     Dua Lipa
# 2                 The Weeknd and Ariana Grande
# 3                                   The Weeknd
# 4                 24kGoldn featuring Iann Dior
# 5                               Olivia Rodrigo
# ..                                         ...
# 96                               Lainey Wilson
# 97                                    BRS Kash
# 98                                    Rod Wave
# 99   Chase Rice featuring Florida Georgia Line
# 100                             Rauw Alejandro
#
# [100 rows x 2 columns]

# %%
def get_auth_key():
    headers = {}
    client_id = ""
    client_secret = ""
    with open("client_id.txt", "r") as infile:
        client_id = infile.read()
        client_id = client_id[ 0 : len(client_id) - 1]
    with open("client_secret.txt", "r") as infile:
        client_secret = infile.read()
        client_secret = client_secret[ 0 : len(client_secret) - 1]
    client_str = f"{client_id}:{client_secret}"
    client_str_bytes = client_str.encode('ascii')
    client_str = b64encode( client_str_bytes ) 
    client_str = client_str.decode('ascii')
    auth_header = f"Basic {client_str}"
    headers['Authorization'] = auth_header
    data = {
        "grant_type" : "client_credentials"
    }
    url = "https://accounts.spotify.com/api/token"
    myreq = r.post(url, headers=headers, data=data)
    status_code = myreq.status_code 
    content = myreq.content.decode('ascii')
    json_data = json.loads(content)
    access_token = json_data['access_token']
    return access_token

# %%
access_token= get_auth_key()

# %%
def do_request():
    artist_name = argv[1]
    url = f"https://api.spotify.com/v1/search?type=artist&q={artist_name}"
    headers = {
        "Accept"        : "application/json",
        "Content-Type"  : "application/json",
    }
    auth_key = get_auth_key()
    headers['Authorization'] = f"Bearer {auth_key}"
    myreq = r.get(url, headers=headers)
    content = myreq.content
    status_code = myreq.status_code 
    if status_code != 200:
        print("Error: status code:", status_code)
        exit(-1)
    json_data = json.loads(content)
    #json_str = json.dumps(json_data, indent=2)
    #print(json_str)
    return json_data

# %%
do_request()
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=-f&type=artist&offset=0&limit=20',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1RyvyyTE3xzB2ZywiAwp0i'},
#     'followers': {'href': None, 'total': 12334490},
#     'genres': ['atl hip hop', 'hip hop', 'rap', 'southern hip hop', 'trap'],
#     'href': 'https://api.spotify.com/v1/artists/1RyvyyTE3xzB2ZywiAwp0i',
#     'id': '1RyvyyTE3xzB2ZywiAwp0i',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb24e41f491b129093a6fee383',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab6761610000517424e41f491b129093a6fee383',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f17824e41f491b129093a6fee383',
#       'width': 160}],
#     'name': 'Future',
#     'popularity': 87,
#     'type': 'artist',
#     'uri': 'spotify:artist:1RyvyyTE3xzB2ZywiAwp0i'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6MzbsLow5TRL1OethtWBw8'},
#     'followers': {'href': None, 'total': 0},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6MzbsLow5TRL1OethtWBw8',
#     'id': '6MzbsLow5TRL1OethtWBw8',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e34aa5d2d82560aa87d973a4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e34aa5d2d82560aa87d973a4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e34aa5d2d82560aa87d973a4',
#       'width': 64}],
#     'name': 'King :3',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:6MzbsLow5TRL1OethtWBw8'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2h93pZq0e7k5yf4dywlkpM'},
#     'followers': {'href': None, 'total': 10131472},
#     'genres': ['hip hop', 'lgbtq+ hip hop', 'neo soul', 'pop'],
#     'href': 'https://api.spotify.com/v1/artists/2h93pZq0e7k5yf4dywlkpM',
#     'id': '2h93pZq0e7k5yf4dywlkpM',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebfbc3faec4a370d8393bee7f1',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174fbc3faec4a370d8393bee7f1',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178fbc3faec4a370d8393bee7f1',
#       'width': 160}],
#     'name': 'Frank Ocean',
#     'popularity': 83,
#     'type': 'artist',
#     'uri': 'spotify:artist:2h93pZq0e7k5yf4dywlkpM'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6AsK790zbD3PJpTAqje1RY'},
#     'followers': {'href': None, 'total': 2},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6AsK790zbD3PJpTAqje1RY',
#     'id': '6AsK790zbD3PJpTAqje1RY',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273243f85754d8f3d2b17160d70',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02243f85754d8f3d2b17160d70',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851243f85754d8f3d2b17160d70',
#       'width': 64}],
#     'name': 'LillaMy',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:6AsK790zbD3PJpTAqje1RY'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/08GQAI4eElDnROBrJRGE0X'},
#     'followers': {'href': None, 'total': 8873855},
#     'genres': ['album rock',
#      'classic rock',
#      'rock',
#      'soft rock',
#      'yacht rock'],
#     'href': 'https://api.spotify.com/v1/artists/08GQAI4eElDnROBrJRGE0X',
#     'id': '08GQAI4eElDnROBrJRGE0X',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb249d55f2d68a44637905c57e',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174249d55f2d68a44637905c57e',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178249d55f2d68a44637905c57e',
#       'width': 160}],
#     'name': 'Fleetwood Mac',
#     'popularity': 78,
#     'type': 'artist',
#     'uri': 'spotify:artist:08GQAI4eElDnROBrJRGE0X'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2W0pknZS43CCFnF0vetV6t'},
#     'followers': {'href': None, 'total': 0},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/2W0pknZS43CCFnF0vetV6t',
#     'id': '2W0pknZS43CCFnF0vetV6t',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27385253605ccee63d12b9c6383',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0285253605ccee63d12b9c6383',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485185253605ccee63d12b9c6383',
#       'width': 64}],
#     'name': 'Kalpna,Tinku Yadav,Raj Nandani',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:2W0pknZS43CCFnF0vetV6t'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2LRoIwlKmHjgvigdNGBHNo'},
#     'followers': {'href': None, 'total': 2448737},
#     'genres': ['colombian pop',
#      'pop reggaeton',
#      'reggaeton colombiano',
#      'trap latino'],
#     'href': 'https://api.spotify.com/v1/artists/2LRoIwlKmHjgvigdNGBHNo',
#     'id': '2LRoIwlKmHjgvigdNGBHNo',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb9aa590e5380864fe4784ab02',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051749aa590e5380864fe4784ab02',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1789aa590e5380864fe4784ab02',
#       'width': 160}],
#     'name': 'Feid',
#     'popularity': 88,
#     'type': 'artist',
#     'uri': 'spotify:artist:2LRoIwlKmHjgvigdNGBHNo'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5DHUBzfAf685QnqVVp78fZ'},
#     'followers': {'href': None, 'total': 0},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/5DHUBzfAf685QnqVVp78fZ',
#     'id': '5DHUBzfAf685QnqVVp78fZ',
#     'images': [],
#     'name': 'Kwaddy',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:5DHUBzfAf685QnqVVp78fZ'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3b8QkneNDz4JHKKKlLgYZg'},
#     'followers': {'href': None, 'total': 4953872},
#     'genres': ['contemporary country',
#      'country',
#      'country pop',
#      'country road',
#      'modern country rock'],
#     'href': 'https://api.spotify.com/v1/artists/3b8QkneNDz4JHKKKlLgYZg',
#     'id': '3b8QkneNDz4JHKKKlLgYZg',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebaa2d9bd207a62adc3edf6631',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174aa2d9bd207a62adc3edf6631',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178aa2d9bd207a62adc3edf6631',
#       'width': 160}],
#     'name': 'Florida Georgia Line',
#     'popularity': 75,
#     'type': 'artist',
#     'uri': 'spotify:artist:3b8QkneNDz4JHKKKlLgYZg'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6MzoajRoOZ9GE6EuZJ4zUL'},
#     'followers': {'href': None, 'total': 0},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6MzoajRoOZ9GE6EuZJ4zUL',
#     'id': '6MzoajRoOZ9GE6EuZJ4zUL',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d2b0808c5da3437597e0bdcf',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d2b0808c5da3437597e0bdcf',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d2b0808c5da3437597e0bdcf',
#       'width': 64}],
#     'name': 'Graeygod',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:6MzoajRoOZ9GE6EuZJ4zUL'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4UXqAaa6dQYAk18Lv7PEgX'},
#     'followers': {'href': None, 'total': 9599293},
#     'genres': ['emo', 'modern rock'],
#     'href': 'https://api.spotify.com/v1/artists/4UXqAaa6dQYAk18Lv7PEgX',
#     'id': '4UXqAaa6dQYAk18Lv7PEgX',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb1443b137c8941b9c73237a27',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051741443b137c8941b9c73237a27',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1781443b137c8941b9c73237a27',
#       'width': 160}],
#     'name': 'Fall Out Boy',
#     'popularity': 77,
#     'type': 'artist',
#     'uri': 'spotify:artist:4UXqAaa6dQYAk18Lv7PEgX'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7Dqe9glqH5aRrBlv1dLSdG'},
#     'followers': {'href': None, 'total': 0},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/7Dqe9glqH5aRrBlv1dLSdG',
#     'id': '7Dqe9glqH5aRrBlv1dLSdG',
#     'images': [],
#     'name': 'Bentley Bodega',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:7Dqe9glqH5aRrBlv1dLSdG'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/329e4yvIujISKGKz1BZZbO'},
#     'followers': {'href': None, 'total': 14194803},
#     'genres': ['latin hip hop', 'reggaeton', 'trap latino'],
#     'href': 'https://api.spotify.com/v1/artists/329e4yvIujISKGKz1BZZbO',
#     'id': '329e4yvIujISKGKz1BZZbO',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebd086033e9cb8291e7be185df',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174d086033e9cb8291e7be185df',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178d086033e9cb8291e7be185df',
#       'width': 160}],
#     'name': 'Farruko',
#     'popularity': 84,
#     'type': 'artist',
#     'uri': 'spotify:artist:329e4yvIujISKGKz1BZZbO'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2j5dGisEPNqXfVkixmCbLw'},
#     'followers': {'href': None, 'total': 2},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/2j5dGisEPNqXfVkixmCbLw',
#     'id': '2j5dGisEPNqXfVkixmCbLw',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273da7d0f27a2359afaeca6df07',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02da7d0f27a2359afaeca6df07',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851da7d0f27a2359afaeca6df07',
#       'width': 64}],
#     'name': 'Bank$4L',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:2j5dGisEPNqXfVkixmCbLw'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0ys2OFYzWYB5hRDLCsBqxt'},
#     'followers': {'href': None, 'total': 1955436},
#     'genres': ['corrido',
#      'corridos tumbados',
#      'musica mexicana',
#      'nueva musica mexicana',
#      'sad sierreno',
#      'sierreno'],
#     'href': 'https://api.spotify.com/v1/artists/0ys2OFYzWYB5hRDLCsBqxt',
#     'id': '0ys2OFYzWYB5hRDLCsBqxt',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebeb9c852bc6587528a4c9cb85',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174eb9c852bc6587528a4c9cb85',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178eb9c852bc6587528a4c9cb85',
#       'width': 160}],
#     'name': 'Fuerza Regida',
#     'popularity': 77,
#     'type': 'artist',
#     'uri': 'spotify:artist:0ys2OFYzWYB5hRDLCsBqxt'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0I3JxY02KiqHVb5UaFfdJj'},
#     'followers': {'href': None, 'total': 4},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/0I3JxY02KiqHVb5UaFfdJj',
#     'id': '0I3JxY02KiqHVb5UaFfdJj',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f9587a6b339fc3821817156b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f9587a6b339fc3821817156b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f9587a6b339fc3821817156b',
#       'width': 64}],
#     'name': 'Dominique Pari',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:0I3JxY02KiqHVb5UaFfdJj'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5t28BP42x2axFnqOOMg3CM'},
#     'followers': {'href': None, 'total': 5693091},
#     'genres': ['alternative metal', 'groove metal', 'nu metal'],
#     'href': 'https://api.spotify.com/v1/artists/5t28BP42x2axFnqOOMg3CM',
#     'id': '5t28BP42x2axFnqOOMg3CM',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb376e2b4db1209bc343daaf35',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174376e2b4db1209bc343daaf35',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178376e2b4db1209bc343daaf35',
#       'width': 160}],
#     'name': 'Five Finger Death Punch',
#     'popularity': 74,
#     'type': 'artist',
#     'uri': 'spotify:artist:5t28BP42x2axFnqOOMg3CM'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4PkPiR7XICYgOaOf7NltrI'},
#     'followers': {'href': None, 'total': 3},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4PkPiR7XICYgOaOf7NltrI',
#     'id': '4PkPiR7XICYgOaOf7NltrI',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273415b150128f1918cb2097e61',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02415b150128f1918cb2097e61',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851415b150128f1918cb2097e61',
#       'width': 64}],
#     'name': 'Kyle Shaw',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:4PkPiR7XICYgOaOf7NltrI'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7jy3rLJdDQY21OgRLCZ9sD'},
#     'followers': {'href': None, 'total': 10307487},
#     'genres': ['alternative metal',
#      'alternative rock',
#      'modern rock',
#      'permanent wave',
#      'post-grunge',
#      'rock'],
#     'href': 'https://api.spotify.com/v1/artists/7jy3rLJdDQY21OgRLCZ9sD',
#     'id': '7jy3rLJdDQY21OgRLCZ9sD',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb9a43b87b50cd3d03544bb3e5',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051749a43b87b50cd3d03544bb3e5',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1789a43b87b50cd3d03544bb3e5',
#       'width': 160}],
#     'name': 'Foo Fighters',
#     'popularity': 77,
#     'type': 'artist',
#     'uri': 'spotify:artist:7jy3rLJdDQY21OgRLCZ9sD'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/01Zelhcx6PHSrzzzWxXIwx'},
#     'followers': {'href': None, 'total': 1},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/01Zelhcx6PHSrzzzWxXIwx',
#     'id': '01Zelhcx6PHSrzzzWxXIwx',
#     'images': [],
#     'name': 'Murga La Pior es na´',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:01Zelhcx6PHSrzzzWxXIwx'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=-f&type=artist&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 10039}}

# %%
def format_json_data(json_data):
    artists = json_data['artists']
    items = artists['items']
    for item in items:
        name = item['name']
        artist_id = item['id']
        genres = ",".join( item['genres'] )
        if genres=="":
            continue
        return(name, artist_id, genres)

# %%
top_us100_dict={}

for i in top100us_data:
    do_request()
    format_json_data(json_data)
    top_us100_dict[name].append(artist_id)
    
top_us100_dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [31], in <cell line: 3>()
#       3 for i in top100us_data:
#       4     do_request()
# ----> 5     format_json_data(json_data)
#       6     top_us100_dict[name].append(artist_id)
#       8 top_us100_dict
#
# NameError: name 'json_data' is not defined
