# %%
import pandas as pd
import matplotlib.pyplot as pp
import numpy as np
import seaborn as sns
import os
from urllib.request import urlopen, Request
import requests as r
from sys import argv, exit
from base64 import b64encode
import json

from dotenv import load_dotenv, find_dotenv
dotenv_path=find_dotenv()
load_dotenv(dotenv_path)
client_id= os.environ.get('SPOTIFY_CLIENT_ID')
client_secret= os.environ.get('SPOTIFY_CLIENT_SECRET')

import spotipy
import sys
from sys import argv, exit
from spotipy.oauth2 import SpotifyClientCredentials

#Authentication without user
client_credentials_manager= SpotifyClientCredentials(client_id= client_id, client_secret=client_secret)
sp= spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
client_secret
# Out:
# 'b80b9ffa98cf4967903f4c159377244c'

# %%
kpop_00_data= pd.read_csv('/Users/josephlim/Downloads/KPopHits2000.csv')
kpop_21_data=pd.read_csv('/Users/josephlim/Downloads/KPopHits2021.csv')
us_98to20_data=pd.read_csv('/Users/josephlim/Downloads/songs_normalize.csv')
us_21_data= pd.read_csv('/Users/josephlim/Downloads/spotify-charts.csv')

# %%
kpop_00_data.isna().any()
# Out:
# Unnamed: 0        False
# title             False
# artist/s          False
# danceability      False
# energy            False
# key               False
# loudness          False
# mode              False
# speechiness       False
# acousticness      False
# valence           False
# tempo             False
# duration_ms       False
# time_signature    False
# dtype: bool

# %%
kpop_21_data.isna().any()
# Out:
# Unnamed: 0        False
# title             False
# artist/s          False
# danceability      False
# energy            False
# key               False
# loudness          False
# mode              False
# speechiness       False
# acousticness      False
# valence           False
# tempo             False
# duration_ms       False
# time_signature    False
# dtype: bool

# %%
us_21_data.isna().any()
# Out:
# Unnamed: 0           False
# Position             False
# Track Name           False
# Streams              False
# Chart Start Date     False
# Chart End Date       False
# Album Name           False
# Release Date         False
# Artist               False
# Features             False
# Song Duration(ms)    False
# Explicit             False
# Url                  False
# dtype: bool

# %%
us_98to20_data.isna().any()
# Out:
# artist              False
# song                False
# duration_ms         False
# explicit            False
# year                False
# popularity          False
# danceability        False
# energy              False
# key                 False
# loudness            False
# mode                False
# speechiness         False
# acousticness        False
# instrumentalness    False
# liveness            False
# valence             False
# tempo               False
# genre               False
# dtype: bool

# %%
kpop_00_data.describe()
# Out:
#        Unnamed: 0  danceability     energy        key   loudness       mode  \
# count   30.000000     30.000000  30.000000  30.000000  30.000000  30.000000
# mean    14.500000      0.605633   0.676100   4.233333  -6.617667   0.566667
# std      8.803408      0.155947   0.213711   3.793673   3.568555   0.504007
# min      0.000000      0.330000   0.233000   0.000000 -15.467000   0.000000
# 25%      7.250000      0.474000   0.530750   0.000000  -7.800500   0.000000
# 50%     14.500000      0.631500   0.736500   3.500000  -6.134500   1.000000
# 75%     21.750000      0.729000   0.833000   8.000000  -4.090250   1.000000
# max     29.000000      0.838000   0.997000   9.000000  -1.820000   1.000000
#
#        speechiness  acousticness    valence       tempo    duration_ms  \
# count    30.000000     30.000000  30.000000   30.000000      30.000000
# mean      0.058683      0.239880   0.545703  127.925267  242037.000000
# std       0.040504      0.264849   0.280608   25.270631   54347.072547
# min       0.026900      0.000427   0.082100   74.692000   48248.000000
# 25%       0.034425      0.028625   0.250000  118.443750  215259.250000
# 50%       0.042150      0.118000   0.656500  132.017000  236705.500000
# 75%       0.066825      0.405250   0.733500  142.283500  260552.250000
# max       0.180000      0.913000   0.971000  179.482000  340907.000000
#
#        time_signature
# count       30.000000
# mean         3.966667
# std          0.182574
# min          3.000000
# 25%          4.000000
# 50%          4.000000
# 75%          4.000000
# max          4.000000

# %%
kpop_21_data.describe()
# Out:
#        Unnamed: 0  danceability     energy        key   loudness       mode  \
# count    50.00000     50.000000  50.000000  50.000000  50.000000  50.000000
# mean     24.50000      0.681860   0.787920   5.280000  -3.790740   0.620000
# std      14.57738      0.117991   0.127271   3.779861   1.976335   0.490314
# min       0.00000      0.311000   0.377000   0.000000 -10.121000   0.000000
# 25%      12.25000      0.609000   0.735750   1.250000  -5.040500   0.000000
# 50%      24.50000      0.690500   0.818500   6.000000  -3.593000   1.000000
# 75%      36.75000      0.765500   0.869750   9.000000  -2.230000   1.000000
# max      49.00000      0.883000   0.963000  11.000000  -0.384000   1.000000
#
#        speechiness  acousticness    valence       tempo    duration_ms  \
# count    50.000000     50.000000  50.000000   50.000000      50.000000
# mean      0.089900      0.097556   0.577220  126.758600  197322.080000
# std       0.053693      0.123401   0.192103   27.460848   20728.437265
# min       0.035100      0.000707   0.135000   61.450000  149214.000000
# 25%       0.054075      0.018575   0.445500  109.985750  184140.250000
# 50%       0.076800      0.054650   0.638000  124.975500  195680.000000
# 75%       0.103250      0.118500   0.721250  147.963250  212248.500000
# max       0.280000      0.594000   0.922000  188.700000  247360.000000
#
#        time_signature
# count            50.0
# mean              4.0
# std               0.0
# min               4.0
# 25%               4.0
# 50%               4.0
# 75%               4.0
# max               4.0

# %%
us_21_data.describe()
# Out:
#         Unnamed: 0     Position  Song Duration(ms)
# count  1260.000000  1260.000000        1260.000000
# mean    629.500000    15.500000      198219.403175
# std     363.874979     8.658878       38673.538380
# min       0.000000     1.000000      121572.000000
# 25%     314.750000     8.000000      170813.000000
# 50%     629.500000    15.500000      199604.000000
# 75%     944.250000    23.000000      216258.250000
# max    1259.000000    30.000000      383036.000000

# %%
us_98to20_data.describe()
# Out:
#          duration_ms        year   popularity  danceability       energy  \
# count    2000.000000  2000.00000  2000.000000   2000.000000  2000.000000
# mean   228748.124500  2009.49400    59.872500      0.667438     0.720366
# std     39136.569008     5.85996    21.335577      0.140416     0.152745
# min    113000.000000  1998.00000     0.000000      0.129000     0.054900
# 25%    203580.000000  2004.00000    56.000000      0.581000     0.622000
# 50%    223279.500000  2010.00000    65.500000      0.676000     0.736000
# 75%    248133.000000  2015.00000    73.000000      0.764000     0.839000
# max    484146.000000  2020.00000    89.000000      0.975000     0.999000
#
#                key     loudness         mode  speechiness  acousticness  \
# count  2000.000000  2000.000000  2000.000000  2000.000000   2000.000000
# mean      5.378000    -5.512434     0.553500     0.103568      0.128955
# std       3.615059     1.933482     0.497254     0.096159      0.173346
# min       0.000000   -20.514000     0.000000     0.023200      0.000019
# 25%       2.000000    -6.490250     0.000000     0.039600      0.014000
# 50%       6.000000    -5.285000     1.000000     0.059850      0.055700
# 75%       8.000000    -4.167750     1.000000     0.129000      0.176250
# max      11.000000    -0.276000     1.000000     0.576000      0.976000
#
#        instrumentalness     liveness      valence        tempo
# count       2000.000000  2000.000000  2000.000000  2000.000000
# mean           0.015226     0.181216     0.551690   120.122558
# std            0.087771     0.140669     0.220864    26.967112
# min            0.000000     0.021500     0.038100    60.019000
# 25%            0.000000     0.088100     0.386750    98.985750
# 50%            0.000000     0.124000     0.557500   120.021500
# 75%            0.000068     0.241000     0.730000   134.265500
# max            0.985000     0.853000     0.973000   210.851000

# %%
us_21_data.head()
# Out:
#    Unnamed: 0  Position                                        Track Name  \
# 0           0         1                              Easy On Me by Adele
# 1           1         2       STAY (with Justin Bieber) by The Kid LAROI
# 2           2         3   INDUSTRY BABY (feat. Jack Harlow) by Lil Nas X
# 3           3         4                      Heat Waves by Glass Animals
# 4           4         5                                    MONEY by LISA
#
#       Streams Chart Start Date Chart End Date                  Album Name  \
# 0  57,081,735       2021-10-22     2021-10-29                  Easy On Me
# 1  43,772,708       2021-10-22     2021-10-29       F*CK LOVE 3: OVER YOU
# 2  38,131,363       2021-10-22     2021-10-29                     MONTERO
# 3  30,071,945       2021-10-22     2021-10-29  Dreamland (+ Bonus Levels)
# 4  27,961,856       2021-10-22     2021-10-29                      LALISA
#
#   Release Date         Artist       Features  Song Duration(ms)  Explicit  \
# 0   2021-10-14          Adele           None             224694     False
# 1   2021-07-23  The Kid LAROI  Justin Bieber             141805      True
# 2   2021-09-17      Lil Nas X    Jack Harlow             212352      True
# 3   2020-08-06  Glass Animals           None             238805     False
# 4   2021-09-10           LISA           None             168227     False
#
#                                                  Url
# 0  https://open.spotify.com/track/0gplL1WMoJ6iYaP...
# 1  https://open.spotify.com/track/5PjdY0CKGZdEuoN...
# 2  https://open.spotify.com/track/5Z9KJZvQzH6PFmb...
# 3  https://open.spotify.com/track/02MWAaffLxlfxAU...
# 4  https://open.spotify.com/track/7hU3IHwjX150XLo...

# %%
top100_USA2021_url= 'https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2021#cite_note-4'
top100us_data= pd.read_html(top100_USA2021_url)

# %%
type(top100us_data)
# Out:
# list

# %%
len(top100us_data)
# Out:
# 2

# %%
top100us_data=top100us_data[0]

# %%
top100us_data= top100us_data.iloc[:,:3]
top100us_data
# Out:
#     No.                                Title  \
# 0     1                         "Levitating"
# 1     2                    "Save Your Tears"
# 2     3                    "Blinding Lights"
# 3     4                               "Mood"
# 4     5                           "Good 4 U"
# ..  ...                                  ...
# 95   96           "Things a Man Oughta Know"
# 96   97              "Throat Baby (Go Baby)"
# 97   98                          "Tombstone"
# 98   99  "Drinkin' Beer. Talkin' God. Amen."
# 99  100                         "Todo de Ti"
#
#                                     Artist(s)
# 0                                    Dua Lipa
# 1                The Weeknd and Ariana Grande
# 2                                  The Weeknd
# 3                24kGoldn featuring Iann Dior
# 4                              Olivia Rodrigo
# ..                                        ...
# 95                              Lainey Wilson
# 96                                   BRS Kash
# 97                                   Rod Wave
# 98  Chase Rice featuring Florida Georgia Line
# 99                             Rauw Alejandro
#
# [100 rows x 3 columns]

# %%
top100us_data.set_index('No.', inplace=True)
top100us_data
# Out:
#                                    Title  \
# No.
# 1                           "Levitating"
# 2                      "Save Your Tears"
# 3                      "Blinding Lights"
# 4                                 "Mood"
# 5                             "Good 4 U"
# ..                                   ...
# 96            "Things a Man Oughta Know"
# 97               "Throat Baby (Go Baby)"
# 98                           "Tombstone"
# 99   "Drinkin' Beer. Talkin' God. Amen."
# 100                         "Todo de Ti"
#
#                                      Artist(s)
# No.
# 1                                     Dua Lipa
# 2                 The Weeknd and Ariana Grande
# 3                                   The Weeknd
# 4                 24kGoldn featuring Iann Dior
# 5                               Olivia Rodrigo
# ..                                         ...
# 96                               Lainey Wilson
# 97                                    BRS Kash
# 98                                    Rod Wave
# 99   Chase Rice featuring Florida Georgia Line
# 100                             Rauw Alejandro
#
# [100 rows x 2 columns]

# %%
top100us_data.columns
# Out:
# Index(['Title', 'Artist(s)'], dtype='object')

# %%
def get_auth_key():
    headers = {}
    client_id = ""
    client_secret = ""
    with open("client_id.txt", "r") as infile:
        client_id = infile.read()
        client_id = client_id[ 0 : len(client_id) - 1]
    with open("client_secret.txt", "r") as infile:
        client_secret = infile.read()
        client_secret = client_secret[ 0 : len(client_secret) - 1]
    client_str = f"{client_id}:{client_secret}"
    client_str_bytes = client_str.encode('ascii')
    client_str = b64encode( client_str_bytes ) 
    client_str = client_str.decode('ascii')
    auth_header = f"Basic {client_str}"
    headers['Authorization'] = auth_header
    data = {
        "grant_type" : "client_credentials"
    }
    url = "https://accounts.spotify.com/api/token"
    myreq = r.post(url, headers=headers, data=data)
    status_code = myreq.status_code 
    content = myreq.content.decode('ascii')
    json_data = json.loads(content)
    access_token = json_data['access_token']
    return access_token

# %%
access_token= get_auth_key()

# %%
def do_request(title, artist):
#     artist_name = argv[1]
#     print(artist_name)
    url = f"https://api.spotify.com/v1/search?q=track:{title}%20artist:{artist}&type=track,artist"
    
    headers = {
        "Accept"        : "application/json",
        "Content-Type"  : "application/json",
    }
    auth_key = get_auth_key()
    headers['Authorization'] = f"Bearer {auth_key}"
    myreq = r.get(url, headers=headers)
    content = myreq.content
    status_code = myreq.status_code 
    if status_code != 200:
        print("Error: status code:", status_code)
        exit(-1)
    json_data = json.loads(content)
    #json_str = json.dumps(json_data, indent=2)
    #print(json_str)
    return json_data

# %%
temp= do_request('Levitating', 'Dua Lipa')  #testing do_request()
temp
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=track%3ALevitating+artist%3ADua+Lipa&type=artist&offset=0&limit=20',
#   'items': [],
#   'limit': 20,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 0},
#  'tracks': {'href': 'https://api.spotify.com/v1/search?query=track%3ALevitating+artist%3ADua+Lipa&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#        'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#        'id': '6M2wZ9GZgrQXHCFfjv46we',
#        'name': 'Dua Lipa',
#        'type': 'artist',
#        'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5lKlFlReHOLShQKyRv6AL9'},
#      'href': 'https://api.spotify.com/v1/albums/5lKlFlReHOLShQKyRv6AL9',
#      'id': '5lKlFlReHOLShQKyRv6AL9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d4daf28d55fe4197ede848be',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d4daf28d55fe4197ede848be',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d4daf28d55fe4197ede848be',
#        'width': 64}],
#      'name': 'Future Nostalgia',
#      'release_date': '2020-03-27',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:5lKlFlReHOLShQKyRv6AL9'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#       'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#       'id': '6M2wZ9GZgrQXHCFfjv46we',
#       'name': 'Dua Lipa',
#       'type': 'artist',
#       'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4r63FhuTkUYltbVAg5TQnk'},
#       'href': 'https://api.spotify.com/v1/artists/4r63FhuTkUYltbVAg5TQnk',
#       'id': '4r63FhuTkUYltbVAg5TQnk',
#       'name': 'DaBaby',
#       'type': 'artist',
#       'uri': 'spotify:artist:4r63FhuTkUYltbVAg5TQnk'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 203064,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHT2000942'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5nujrmhLynf4yMoMtj8AQF'},
#     'href': 'https://api.spotify.com/v1/tracks/5nujrmhLynf4yMoMtj8AQF',
#     'id': '5nujrmhLynf4yMoMtj8AQF',
#     'is_local': False,
#     'name': 'Levitating (feat. DaBaby)',
#     'popularity': 84,
#     'preview_url': 'https://p.scdn.co/mp3-preview/baa8859b39dc78685642e1adfe60ec5ef8b3a5cf?cid=812359738382417c83f56ce5fcaf851a',
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:5nujrmhLynf4yMoMtj8AQF'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#        'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#        'id': '6M2wZ9GZgrQXHCFfjv46we',
#        'name': 'Dua Lipa',
#        'type': 'artist',
#        'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7fJJK56U9fHixgO0HQkhtI'},
#      'href': 'https://api.spotify.com/v1/albums/7fJJK56U9fHixgO0HQkhtI',
#      'id': '7fJJK56U9fHixgO0HQkhtI',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bd26ede1ae69327010d49946',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bd26ede1ae69327010d49946',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bd26ede1ae69327010d49946',
#        'width': 64}],
#      'name': 'Future Nostalgia',
#      'release_date': '2020-03-27',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:7fJJK56U9fHixgO0HQkhtI'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#       'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#       'id': '6M2wZ9GZgrQXHCFfjv46we',
#       'name': 'Dua Lipa',
#       'type': 'artist',
#       'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 203807,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHT1901299'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/39LLxExYz6ewLAcYrzQQyP'},
#     'href': 'https://api.spotify.com/v1/tracks/39LLxExYz6ewLAcYrzQQyP',
#     'id': '39LLxExYz6ewLAcYrzQQyP',
#     'is_local': False,
#     'name': 'Levitating',
#     'popularity': 82,
#     'preview_url': 'https://p.scdn.co/mp3-preview/130e18a8f12e319b06032640c6b75e3881719684?cid=812359738382417c83f56ce5fcaf851a',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:39LLxExYz6ewLAcYrzQQyP'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AR',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BG',
#       'BH',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BZ',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CW',
#       'CY',
#       'CZ',
#       'DK',
#       'DM',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GB',
#       'GD',
#       'GE',
#       'GR',
#       'GT',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KG',
#       'KH',
#       'KI',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MD',
#       'ME',
#       'MH',
#       'MK',
#       'MN',
#       'MO',
#       'MT',
#       'MV',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'SA',
#       'SB',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SM',
#       'SR',
#       'SV',
#       'TH',
#       'TJ',
#       'TL',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4VSML7YwI6AFaBq8LLGi1H'},
#      'href': 'https://api.spotify.com/v1/albums/4VSML7YwI6AFaBq8LLGi1H',
#      'id': '4VSML7YwI6AFaBq8LLGi1H',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f580be6bd4c41a1903f51a55',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f580be6bd4c41a1903f51a55',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f580be6bd4c41a1903f51a55',
#        'width': 64}],
#      'name': 'Top Hits van 2022',
#      'release_date': '2022-12-16',
#      'release_date_precision': 'day',
#      'total_tracks': 42,
#      'type': 'album',
#      'uri': 'spotify:album:4VSML7YwI6AFaBq8LLGi1H'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#       'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#       'id': '6M2wZ9GZgrQXHCFfjv46we',
#       'name': 'Dua Lipa',
#       'type': 'artist',
#       'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4r63FhuTkUYltbVAg5TQnk'},
#       'href': 'https://api.spotify.com/v1/artists/4r63FhuTkUYltbVAg5TQnk',
#       'id': '4r63FhuTkUYltbVAg5TQnk',
#       'name': 'DaBaby',
#       'type': 'artist',
#       'uri': 'spotify:artist:4r63FhuTkUYltbVAg5TQnk'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AR',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BG',
#      'BH',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BZ',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CW',
#      'CY',
#      'CZ',
#      'DK',
#      'DM',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GB',
#      'GD',
#      'GE',
#      'GR',
#      'GT',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KG',
#      'KH',
#      'KI',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MD',
#      'ME',
#      'MH',
#      'MK',
#      'MN',
#      'MO',
#      'MT',
#      'MV',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SA',
#      'SB',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SM',
#      'SR',
#      'SV',
#      'TH',
#      'TJ',
#      'TL',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 203064,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHT2000942'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0GztBLd0CGoCDjhrj3apAg'},
#     'href': 'https://api.spotify.com/v1/tracks/0GztBLd0CGoCDjhrj3apAg',
#     'id': '0GztBLd0CGoCDjhrj3apAg',
#     'is_local': False,
#     'name': 'Levitating',
#     'popularity': 3,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3953fd37adfead10a7bc1bab1fd0e07279f41766?cid=812359738382417c83f56ce5fcaf851a',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0GztBLd0CGoCDjhrj3apAg'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NO',
#       'NP',
#       'NR',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0DQP8EzDkzoxcElCRjlA9o'},
#      'href': 'https://api.spotify.com/v1/albums/0DQP8EzDkzoxcElCRjlA9o',
#      'id': '0DQP8EzDkzoxcElCRjlA9o',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c36b329d9ebd5978956e49fe',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c36b329d9ebd5978956e49fe',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c36b329d9ebd5978956e49fe',
#        'width': 64}],
#      'name': 'Rainbow Mix',
#      'release_date': '2022-12-23',
#      'release_date_precision': 'day',
#      'total_tracks': 37,
#      'type': 'album',
#      'uri': 'spotify:album:0DQP8EzDkzoxcElCRjlA9o'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#       'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#       'id': '6M2wZ9GZgrQXHCFfjv46we',
#       'name': 'Dua Lipa',
#       'type': 'artist',
#       'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NO',
#      'NP',
#      'NR',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 203807,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHT1901299'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4FGUrSJosheu0lGKnDp3Zm'},
#     'href': 'https://api.spotify.com/v1/tracks/4FGUrSJosheu0lGKnDp3Zm',
#     'id': '4FGUrSJosheu0lGKnDp3Zm',
#     'is_local': False,
#     'name': 'Levitating',
#     'popularity': 2,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ca6868fb1967e39d720d085a4e6e62284a7e9e33?cid=812359738382417c83f56ce5fcaf851a',
#     'track_number': 24,
#     'type': 'track',
#     'uri': 'spotify:track:4FGUrSJosheu0lGKnDp3Zm'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AR',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BG',
#       'BH',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BZ',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CW',
#       'CY',
#       'CZ',
#       'DK',
#       'DM',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GB',
#       'GD',
#       'GE',
#       'GR',
#       'GT',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'KG',
#       'KH',
#       'KI',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MD',
#       'ME',
#       'MH',
#       'MK',
#       'MN',
#       'MO',
#       'MT',
#       'MV',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'SA',
#       'SB',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SM',
#       'SR',
#       'SV',
#       'TH',
#       'TJ',
#       'TL',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5pKsMvrxae0Loa69HfczqM'},
#      'href': 'https://api.spotify.com/v1/albums/5pKsMvrxae0Loa69HfczqM',
#      'id': '5pKsMvrxae0Loa69HfczqM',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273933730327c1644be5ff9c3af',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02933730327c1644be5ff9c3af',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851933730327c1644be5ff9c3af',
#        'width': 64}],
#      'name': 'Top Feelgood',
#      'release_date': '2022-12-23',
#      'release_date_precision': 'day',
#      'total_tracks': 28,
#      'type': 'album',
#      'uri': 'spotify:album:5pKsMvrxae0Loa69HfczqM'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#       'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#       'id': '6M2wZ9GZgrQXHCFfjv46we',
#       'name': 'Dua Lipa',
#       'type': 'artist',
#       'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AR',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BG',
#      'BH',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BZ',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CW',
#      'CY',
#      'CZ',
#      'DK',
#      'DM',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GB',
#      'GD',
#      'GE',
#      'GR',
#      'GT',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'KG',
#      'KH',
#      'KI',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MD',
#      'ME',
#      'MH',
#      'MK',
#      'MN',
#      'MO',
#      'MT',
#      'MV',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SA',
#      'SB',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SM',
#      'SR',
#      'SV',
#      'TH',
#      'TJ',
#      'TL',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 203807,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHT1901299'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7eE6Bci5m7ZG6qW2VH7m0z'},
#     'href': 'https://api.spotify.com/v1/tracks/7eE6Bci5m7ZG6qW2VH7m0z',
#     'id': '7eE6Bci5m7ZG6qW2VH7m0z',
#     'is_local': False,
#     'name': 'Levitating',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ca6868fb1967e39d720d085a4e6e62284a7e9e33?cid=812359738382417c83f56ce5fcaf851a',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:7eE6Bci5m7ZG6qW2VH7m0z'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AR',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BG',
#       'BH',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BZ',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CW',
#       'CY',
#       'CZ',
#       'DK',
#       'DM',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GB',
#       'GD',
#       'GE',
#       'GR',
#       'GT',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KG',
#       'KH',
#       'KI',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MD',
#       'ME',
#       'MH',
#       'MK',
#       'MN',
#       'MO',
#       'MT',
#       'MV',
#       'MX',
#       'MY',
#       'NI',
#       'NO',
#       'NP',
#       'NR',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'SA',
#       'SB',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SM',
#       'SR',
#       'SV',
#       'TH',
#       'TJ',
#       'TL',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2SqNsUORLPGikzPMp6FPhe'},
#      'href': 'https://api.spotify.com/v1/albums/2SqNsUORLPGikzPMp6FPhe',
#      'id': '2SqNsUORLPGikzPMp6FPhe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27358dad12940393ce5a5428807',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0258dad12940393ce5a5428807',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485158dad12940393ce5a5428807',
#        'width': 64}],
#      'name': 'Friday Vibes',
#      'release_date': '2022-12-23',
#      'release_date_precision': 'day',
#      'total_tracks': 35,
#      'type': 'album',
#      'uri': 'spotify:album:2SqNsUORLPGikzPMp6FPhe'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#       'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#       'id': '6M2wZ9GZgrQXHCFfjv46we',
#       'name': 'Dua Lipa',
#       'type': 'artist',
#       'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4r63FhuTkUYltbVAg5TQnk'},
#       'href': 'https://api.spotify.com/v1/artists/4r63FhuTkUYltbVAg5TQnk',
#       'id': '4r63FhuTkUYltbVAg5TQnk',
#       'name': 'DaBaby',
#       'type': 'artist',
#       'uri': 'spotify:artist:4r63FhuTkUYltbVAg5TQnk'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AR',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BG',
#      'BH',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BZ',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CW',
#      'CY',
#      'CZ',
#      'DK',
#      'DM',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GB',
#      'GD',
#      'GE',
#      'GR',
#      'GT',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KG',
#      'KH',
#      'KI',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MD',
#      'ME',
#      'MH',
#      'MK',
#      'MN',
#      'MO',
#      'MT',
#      'MV',
#      'MX',
#      'MY',
#      'NI',
#      'NO',
#      'NP',
#      'NR',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SA',
#      'SB',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SM',
#      'SR',
#      'SV',
#      'TH',
#      'TJ',
#      'TL',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 203064,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHT2000942'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4KuIDJQAKFXoXU9kNKxAp6'},
#     'href': 'https://api.spotify.com/v1/tracks/4KuIDJQAKFXoXU9kNKxAp6',
#     'id': '4KuIDJQAKFXoXU9kNKxAp6',
#     'is_local': False,
#     'name': 'Levitating',
#     'popularity': 1,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3953fd37adfead10a7bc1bab1fd0e07279f41766?cid=812359738382417c83f56ce5fcaf851a',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:4KuIDJQAKFXoXU9kNKxAp6'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6HLWyXCHton3FdNwUSQUS7'},
#      'href': 'https://api.spotify.com/v1/albums/6HLWyXCHton3FdNwUSQUS7',
#      'id': '6HLWyXCHton3FdNwUSQUS7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27366a13e5dd1da134ff14c49eb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0266a13e5dd1da134ff14c49eb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485166a13e5dd1da134ff14c49eb',
#        'width': 64}],
#      'name': 'Party Starters',
#      'release_date': '2022-12-16',
#      'release_date_precision': 'day',
#      'total_tracks': 40,
#      'type': 'album',
#      'uri': 'spotify:album:6HLWyXCHton3FdNwUSQUS7'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#       'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#       'id': '6M2wZ9GZgrQXHCFfjv46we',
#       'name': 'Dua Lipa',
#       'type': 'artist',
#       'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 203807,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHT1901299'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2yznOjQdW4R7rp1ai4hC6T'},
#     'href': 'https://api.spotify.com/v1/tracks/2yznOjQdW4R7rp1ai4hC6T',
#     'id': '2yznOjQdW4R7rp1ai4hC6T',
#     'is_local': False,
#     'name': 'Levitating',
#     'popularity': 2,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ca6868fb1967e39d720d085a4e6e62284a7e9e33?cid=812359738382417c83f56ce5fcaf851a',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:2yznOjQdW4R7rp1ai4hC6T'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#        'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#        'id': '6M2wZ9GZgrQXHCFfjv46we',
#        'name': 'Dua Lipa',
#        'type': 'artist',
#        'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4r63FhuTkUYltbVAg5TQnk'},
#        'href': 'https://api.spotify.com/v1/artists/4r63FhuTkUYltbVAg5TQnk',
#        'id': '4r63FhuTkUYltbVAg5TQnk',
#        'name': 'DaBaby',
#        'type': 'artist',
#        'uri': 'spotify:artist:4r63FhuTkUYltbVAg5TQnk'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/04m06KhJUuwe1Q487puIud'},
#      'href': 'https://api.spotify.com/v1/albums/04m06KhJUuwe1Q487puIud',
#      'id': '04m06KhJUuwe1Q487puIud',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27349caa4fc6f962057ba65576a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0249caa4fc6f962057ba65576a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485149caa4fc6f962057ba65576a',
#        'width': 64}],
#      'name': 'Levitating (feat. DaBaby)',
#      'release_date': '2020-10-01',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:04m06KhJUuwe1Q487puIud'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#       'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#       'id': '6M2wZ9GZgrQXHCFfjv46we',
#       'name': 'Dua Lipa',
#       'type': 'artist',
#       'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4r63FhuTkUYltbVAg5TQnk'},
#       'href': 'https://api.spotify.com/v1/artists/4r63FhuTkUYltbVAg5TQnk',
#       'id': '4r63FhuTkUYltbVAg5TQnk',
#       'name': 'DaBaby',
#       'type': 'artist',
#       'uri': 'spotify:artist:4r63FhuTkUYltbVAg5TQnk'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 203064,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHT2000942'},
# ...
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c17893b4b866f75928d7e1c1',
#        'width': 64}],
#      'name': 'Levitating EP',
#      'release_date': '2020-11-20',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:5HaIikztvnTIwx2QA5YsmX'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#       'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#       'id': '6M2wZ9GZgrQXHCFfjv46we',
#       'name': 'Dua Lipa',
#       'type': 'artist',
#       'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 203807,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHT1901299'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6pn6lXv8UjpMFAo9znYOUC'},
#     'href': 'https://api.spotify.com/v1/tracks/6pn6lXv8UjpMFAo9znYOUC',
#     'id': '6pn6lXv8UjpMFAo9znYOUC',
#     'is_local': False,
#     'name': 'Levitating',
#     'popularity': 48,
#     'preview_url': 'https://p.scdn.co/mp3-preview/bd8a7790d31c22c4d1bcf273042e97cf6ede545b?cid=812359738382417c83f56ce5fcaf851a',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:6pn6lXv8UjpMFAo9znYOUC'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#        'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#        'id': '6M2wZ9GZgrQXHCFfjv46we',
#        'name': 'Dua Lipa',
#        'type': 'artist',
#        'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6dr5OXklXimj3DRMhQEYYz'},
#      'href': 'https://api.spotify.com/v1/albums/6dr5OXklXimj3DRMhQEYYz',
#      'id': '6dr5OXklXimj3DRMhQEYYz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739681ff7e0a64cae935cf244a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029681ff7e0a64cae935cf244a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519681ff7e0a64cae935cf244a',
#        'width': 64}],
#      'name': 'Levitating EP',
#      'release_date': '2020-12-11',
#      'release_date_precision': 'day',
#      'total_tracks': 5,
#      'type': 'album',
#      'uri': 'spotify:album:6dr5OXklXimj3DRMhQEYYz'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#       'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#       'id': '6M2wZ9GZgrQXHCFfjv46we',
#       'name': 'Dua Lipa',
#       'type': 'artist',
#       'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 203807,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHT1901299'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/12d6L7D2rRUv6XgF73GBAi'},
#     'href': 'https://api.spotify.com/v1/tracks/12d6L7D2rRUv6XgF73GBAi',
#     'id': '12d6L7D2rRUv6XgF73GBAi',
#     'is_local': False,
#     'name': 'Levitating',
#     'popularity': 35,
#     'preview_url': 'https://p.scdn.co/mp3-preview/bd8a7790d31c22c4d1bcf273042e97cf6ede545b?cid=812359738382417c83f56ce5fcaf851a',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:12d6L7D2rRUv6XgF73GBAi'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2b7ymARfIOZvtZR6YUBzfY'},
#      'href': 'https://api.spotify.com/v1/albums/2b7ymARfIOZvtZR6YUBzfY',
#      'id': '2b7ymARfIOZvtZR6YUBzfY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27330059ce62e43e8040aec77ca',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0230059ce62e43e8040aec77ca',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485130059ce62e43e8040aec77ca',
#        'width': 64}],
#      'name': 'Viral Women',
#      'release_date': '2022-03-08',
#      'release_date_precision': 'day',
#      'total_tracks': 34,
#      'type': 'album',
#      'uri': 'spotify:album:2b7ymARfIOZvtZR6YUBzfY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#       'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#       'id': '6M2wZ9GZgrQXHCFfjv46we',
#       'name': 'Dua Lipa',
#       'type': 'artist',
#       'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 203807,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHT1901299'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6hb8ZDv7KIsn1hZNQ2Qk4p'},
#     'href': 'https://api.spotify.com/v1/tracks/6hb8ZDv7KIsn1hZNQ2Qk4p',
#     'id': '6hb8ZDv7KIsn1hZNQ2Qk4p',
#     'is_local': False,
#     'name': 'Levitating',
#     'popularity': 23,
#     'preview_url': 'https://p.scdn.co/mp3-preview/130e18a8f12e319b06032640c6b75e3881719684?cid=812359738382417c83f56ce5fcaf851a',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:6hb8ZDv7KIsn1hZNQ2Qk4p'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=track%3ALevitating+artist%3ADua+Lipa&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 300}}

# %%
temp['tracks']['items'][0]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#     'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#     'id': '6M2wZ9GZgrQXHCFfjv46we',
#     'name': 'Dua Lipa',
#     'type': 'artist',
#     'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5lKlFlReHOLShQKyRv6AL9'},
#   'href': 'https://api.spotify.com/v1/albums/5lKlFlReHOLShQKyRv6AL9',
#   'id': '5lKlFlReHOLShQKyRv6AL9',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273d4daf28d55fe4197ede848be',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02d4daf28d55fe4197ede848be',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851d4daf28d55fe4197ede848be',
#     'width': 64}],
#   'name': 'Future Nostalgia',
#   'release_date': '2020-03-27',
#   'release_date_precision': 'day',
#   'total_tracks': 13,
#   'type': 'album',
#   'uri': 'spotify:album:5lKlFlReHOLShQKyRv6AL9'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#    'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#    'id': '6M2wZ9GZgrQXHCFfjv46we',
#    'name': 'Dua Lipa',
#    'type': 'artist',
#    'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4r63FhuTkUYltbVAg5TQnk'},
#    'href': 'https://api.spotify.com/v1/artists/4r63FhuTkUYltbVAg5TQnk',
#    'id': '4r63FhuTkUYltbVAg5TQnk',
#    'name': 'DaBaby',
#    'type': 'artist',
#    'uri': 'spotify:artist:4r63FhuTkUYltbVAg5TQnk'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BY',
#   'BZ',
#   'CA',
#   'CD',
#   'CG',
#   'CI',
#   'CL',
#   'CM',
#   'CO',
#   'CR',
#   'CV',
#   'CW',
#   'CY',
#   'CZ',
#   'DJ',
#   'DK',
#   'DM',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FJ',
#   'FM',
#   'FR',
#   'GA',
#   'GB',
#   'GD',
#   'GE',
#   'GH',
#   'GM',
#   'GN',
#   'GQ',
#   'GR',
#   'GT',
#   'GW',
#   'GY',
#   'HK',
#   'HN',
#   'HR',
#   'HT',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IQ',
#   'IS',
#   'IT',
#   'JM',
#   'JO',
#   'JP',
#   'KE',
#   'KG',
#   'KH',
#   'KI',
#   'KM',
#   'KN',
#   'KR',
#   'KW',
#   'KZ',
#   'LA',
#   'LB',
#   'LC',
#   'LI',
#   'LK',
#   'LR',
#   'LS',
#   'LT',
#   'LU',
#   'LV',
#   'LY',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MG',
#   'MH',
#   'MK',
#   'ML',
#   'MN',
#   'MO',
#   'MR',
#   'MT',
#   'MU',
#   'MV',
#   'MW',
#   'MX',
#   'MY',
#   'MZ',
#   'NA',
#   'NE',
#   'NG',
#   'NI',
#   'NL',
#   'NO',
#   'NP',
#   'NR',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PG',
#   'PH',
#   'PK',
#   'PL',
#   'PS',
#   'PT',
#   'PW',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RW',
#   'SA',
#   'SB',
#   'SC',
#   'SG',
#   'SI',
#   'SK',
#   'SL',
#   'SM',
#   'SN',
#   'SR',
#   'ST',
#   'SV',
#   'SZ',
#   'TD',
#   'TG',
#   'TH',
#   'TJ',
#   'TL',
#   'TN',
#   'TO',
#   'TR',
#   'TT',
#   'TV',
#   'TW',
#   'TZ',
#   'UA',
#   'UG',
#   'US',
#   'UY',
#   'UZ',
#   'VC',
#   'VE',
#   'VN',
#   'VU',
#   'WS',
#   'XK',
#   'ZA',
#   'ZM',
#   'ZW'],
#  'disc_number': 1,
#  'duration_ms': 203064,
#  'explicit': False,
#  'external_ids': {'isrc': 'GBAHT2000942'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/5nujrmhLynf4yMoMtj8AQF'},
#  'href': 'https://api.spotify.com/v1/tracks/5nujrmhLynf4yMoMtj8AQF',
#  'id': '5nujrmhLynf4yMoMtj8AQF',
#  'is_local': False,
#  'name': 'Levitating (feat. DaBaby)',
#  'popularity': 84,
#  'preview_url': 'https://p.scdn.co/mp3-preview/baa8859b39dc78685642e1adfe60ec5ef8b3a5cf?cid=812359738382417c83f56ce5fcaf851a',
#  'track_number': 12,
#  'type': 'track',
#  'uri': 'spotify:track:5nujrmhLynf4yMoMtj8AQF'}

# %%
print("\n Track ID is",temp['tracks']['items'][0]['id'])
# Out:
#  Track ID is 5nujrmhLynf4yMoMtj8AQF

# %%
titles=list(top100us_data['Title'])
artists= list(top100us_data['Artist(s)'])

titles
# Out:
# ['"Levitating"',
#  '"Save Your Tears"',
#  '"Blinding Lights"',
#  '"Mood"',
#  '"Good 4 U"',
#  '"Kiss Me More"',
#  '"Leave the Door Open"',
#  '"Drivers License"',
#  '"Montero (Call Me by Your Name)"',
#  '"Peaches"',
#  '"Butter"',
#  '"Stay"',
#  '"Deja Vu"',
#  '"Positions"',
#  '"Bad Habits"',
#  '"Heat Waves"',
#  '"Without You"',
#  '"Forever After All"',
#  '"Go Crazy"',
#  '"Astronaut in the Ocean"',
#  '"34+35"',
#  '"What You Know Bout Love"',
#  '"My Ex\'s Best Friend"',
#  '"Industry Baby"',
#  '"Therefore I Am"',
#  '"Up"',
#  '"Fancy Like"',
#  '"Dakiti"',
#  '"Best Friend"',
#  '"Rapstar"',
#  '"Heartbreak Anniversary"',
#  '"For the Night"',
#  '"Calling My Phone"',
#  '"Beautiful Mistakes"',
#  '"Holy"',
#  '"On Me"',
#  '"You Broke Me First"',
#  '"Traitor"',
#  '"Back in Blood"',
#  '"I Hope"',
#  '"Dynamite"',
#  '"Wockesha"',
#  '"You Right"',
#  '"Beat Box"',
#  '"Laugh Now Cry Later"',
#  '"Need to Know"',
#  '"Wants and Needs"',
#  '"Way 2 Sexy"',
#  '"Telepatía"',
#  '"Whoopty"',
#  '"Lemonade"',
#  '"Good Days"',
#  '"Starting Over"',
#  '"Body"',
#  '"Willow"',
#  '"Bang!"',
#  '"Better Together"',
#  '"You\'re Mines Still"',
#  '"Every Chance I Get"',
#  '"Essence"',
#  '"Chasing After You"',
#  '"The Good Ones"',
#  '"Leave Before You Love Me"',
#  '"Glad You Exist"',
#  '"Lonely"',
#  '"Beggin\'"',
#  '"Streets"',
#  '"What\'s Next"',
#  '"Famous Friends"',
#  '"Lil Bit"',
#  '"Thot Shit"',
#  '"Late at Night"',
#  '"Kings & Queens"',
#  '"Anyone"',
#  '"Track Star"',
#  '"Time Today"',
#  '"Cry Baby"',
#  '"All I Want for Christmas Is You"',
#  '"No More Parties"',
#  '"What\'s Your Country Song"',
#  '"One Too Many"',
#  '"Arcade"',
#  '"Yonaguni"',
#  '"Good Time"',
#  '"If I Didn\'t Love You"',
#  '"Knife Talk"',
#  '"POV"',
#  '"Just the Way"',
#  '"Take My Breath"',
#  '"We\'re Good"',
#  '"Hell of a View"',
#  '"Rockin\' Around the Christmas Tree"',
#  '"Put Your Records On"',
#  '"Happier Than Ever"',
#  '"Single Saturday Night"',
#  '"Things a Man Oughta Know"',
#  '"Throat Baby (Go Baby)"',
#  '"Tombstone"',
#  '"Drinkin\' Beer. Talkin\' God. Amen."',
#  '"Todo de Ti"']

# %%
titles= [item.replace('"','') for item in titles]
titles
# Out:
# ['Levitating',
#  'Save Your Tears',
#  'Blinding Lights',
#  'Mood',
#  'Good 4 U',
#  'Kiss Me More',
#  'Leave the Door Open',
#  'Drivers License',
#  'Montero (Call Me by Your Name)',
#  'Peaches',
#  'Butter',
#  'Stay',
#  'Deja Vu',
#  'Positions',
#  'Bad Habits',
#  'Heat Waves',
#  'Without You',
#  'Forever After All',
#  'Go Crazy',
#  'Astronaut in the Ocean',
#  '34+35',
#  'What You Know Bout Love',
#  "My Ex's Best Friend",
#  'Industry Baby',
#  'Therefore I Am',
#  'Up',
#  'Fancy Like',
#  'Dakiti',
#  'Best Friend',
#  'Rapstar',
#  'Heartbreak Anniversary',
#  'For the Night',
#  'Calling My Phone',
#  'Beautiful Mistakes',
#  'Holy',
#  'On Me',
#  'You Broke Me First',
#  'Traitor',
#  'Back in Blood',
#  'I Hope',
#  'Dynamite',
#  'Wockesha',
#  'You Right',
#  'Beat Box',
#  'Laugh Now Cry Later',
#  'Need to Know',
#  'Wants and Needs',
#  'Way 2 Sexy',
#  'Telepatía',
#  'Whoopty',
#  'Lemonade',
#  'Good Days',
#  'Starting Over',
#  'Body',
#  'Willow',
#  'Bang!',
#  'Better Together',
#  "You're Mines Still",
#  'Every Chance I Get',
#  'Essence',
#  'Chasing After You',
#  'The Good Ones',
#  'Leave Before You Love Me',
#  'Glad You Exist',
#  'Lonely',
#  "Beggin'",
#  'Streets',
#  "What's Next",
#  'Famous Friends',
#  'Lil Bit',
#  'Thot Shit',
#  'Late at Night',
#  'Kings & Queens',
#  'Anyone',
#  'Track Star',
#  'Time Today',
#  'Cry Baby',
#  'All I Want for Christmas Is You',
#  'No More Parties',
#  "What's Your Country Song",
#  'One Too Many',
#  'Arcade',
#  'Yonaguni',
#  'Good Time',
#  "If I Didn't Love You",
#  'Knife Talk',
#  'POV',
#  'Just the Way',
#  'Take My Breath',
#  "We're Good",
#  'Hell of a View',
#  "Rockin' Around the Christmas Tree",
#  'Put Your Records On',
#  'Happier Than Ever',
#  'Single Saturday Night',
#  'Things a Man Oughta Know',
#  'Throat Baby (Go Baby)',
#  'Tombstone',
#  "Drinkin' Beer. Talkin' God. Amen.",
#  'Todo de Ti']

# %%
id_list=[]

for i in range(len(top100us_data)):
    temp=do_request(titles[i], artists[i])
    id_list.append(temp['tracks']['items'][0]['id'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/z9/t15ddpld70nc5qf41442lpr80000gn/T/ipykernel_2581/4029128657.py in <module>
#       3 for i in range(len(top100us_data)):
#       4     temp=do_request(titles[i], artists[i])
# ----> 5     id_list.append(temp['tracks']['items'][0]['id'])
#
# IndexError: list index out of range
